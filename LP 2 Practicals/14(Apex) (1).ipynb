# %%
Title : Creating an Application in SalesForce.com using Apex programming Language

STEPS TO CREATE AN APPLICATION :

Step No 1: Create new org:
https://developer.salesforce.com/signup

Step No 2: After signup, loging using following URL
https://login.salesforce.com/

Step No 3: Login Page (Enter your credential to login)
1. Open Developer Console
2. File ---> New ---> Select Apex Class(enter name to apex class and save Clt+s)
3.Type below mentioned code

public class Sample { 
public Double myValue = 0; 

public Double get() {

myValue = myValue+10;
return myValue;
}
}

step No 4: 
Sample s = new Sample();
system.debug(s.get());      


public class CC_Practical {
    
    public double result;

    public double add(Integer x, Integer y) {
        result = x + y;
        return result;
    }

    public double sub(Integer x, Integer y) {
        result = x - y;
        return result;
    }

    public double multiply(Integer x, Integer y) {
        result = x * y;
        return result;
    }
    
    public double divide(Integer x, Integer y) {
        result = x / y;
        return result;
    }
}
Dont forget to press ctrl+S and save it


CC_Practical c = new CC_Practical();
double sum = c.add(3, 5);
double difference = c.sub(5, 7);
double mul = c.multiply(3, 5);
double division = c.divide(15, 5);

System.debug('Sum=' + sum);
System.debug('Difference=' + difference);
System.debug('Multiply=' + mul);
System.debug('Divide=' + division);

sanjana@dypiemr.sandbox
